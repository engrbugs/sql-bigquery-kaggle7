# %%
from google.cloud import bigquery
import os
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "credentials/endless-beach-228506-b15de187c224.json"

# %%
# Create a "Client" object
client = bigquery.Client()

# Construct a reference to the "stackoverflow" dataset
dataset_ref = client.dataset("stackoverflow", project="bigquery-public-data")

# API request - fetch the dataset
dataset = client.get_dataset(dataset_ref)

# %%
tables = list(client.list_tables(dataset))
list_of_tables = [table.table_id for table in tables]
print(list_of_tables)
# Out:
# ['badges', 'comments', 'post_history', 'post_links', 'posts_answers', 'posts_moderator_nomination', 'posts_orphaned_tag_wiki', 'posts_privilege_wiki', 'posts_questions', 'posts_tag_wiki', 'posts_tag_wiki_excerpt', 'posts_wiki_placeholder', 'stackoverflow_posts', 'tags', 'users', 'votes']

# %%
table_ref = dataset_ref.table("posts_answers")
table = client.get_table(table_ref)
client.list_rows(table, max_results=10).to_dataframe()
# Out:
#          id title                                               body  \
# 0  68472973  None  <p>Thank you.  After thinking through your ans...
# 1  68472974  None  <pre><code>SELECT age((((m.message -&gt; 'head...
# 2  68472975  None  <p>I believe <code>Identifiable</code> is a pr...
# 3  68472976  None  <p>Funny enough I had the same problem with th...
# 4  68472989  None  <p>You either need to set a <code>height</code...
# 5  68473002  None  <p>Even though I could see the JDK has decent ...
# 6  68473005  None  <p>On the Parameter Trend dashboard, you can c...
# 7  68473007  None  <p>Just use the <code>_fields</code> parameter...
# 8  68473008  None  <p>For this case I would combine both calls wi...
# 9  68473009  None  <p>I had the same problem try to use this.</p>...
#
#   accepted_answer_id answer_count  comment_count community_owned_date  \
# 0               None         None              0                 None
# ...

# %%
table_ref = dataset_ref.table("posts_questions")
table = client.get_table(table_ref)
client.list_rows(table, max_results=10).to_dataframe()
# Out:
#          id                                              title  \
# 0  68760184   SpawnPrefabAtGeoLocation with mapbox-streets-v8?
# 1  68776566  Why to use process.nextTick() to call Writeabl...
# 2  68847727       Share button in browser copy old address url
# 3  68863312  Changed a Virtual Switch on a node and destroy...
# 4  69023598  Problem about exporting data by the function “...
# 5  69026372  How to make check boxes using collection view ...
# 6  69031095  cannot copy 0xa0 properly in div - contentEdit...
# 7  69039419  How to use the node media server npm module wi...
# 8  69050631  how to get browser full url of the page in nod...
# 9  69055251  Force failure if Vagrantfile misses environmen...
#
#                                                 body accepted_answer_id  \
# 0  <p>How can we spawn custom prefabs at geo loca...               None
# 1  <p>I was reading the <a href="https://nodejs.o...               None
# ...

# %%
first_query = """
SELECT q.id AS q_id,
    MIN(TIMESTAMP_DIFF(a.creation_date, q.creation_date, SECOND)) as time_to_answer
FROM 'bigquery-public-data.stackoverflow.post_questions' AS q
WHERE q.creation_date >= '2018-01-01' and q.creation_date < '2018-02-01'
"""

safe_config = bigquery.QueryJobConfig()
first_result = client.query(first_query, job_config=safe_config)
first_result.result().to_dataframe()
# Out:
# ---------------------------------------------------------------------------
# BadRequest                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10080/4233950867.py in <module>
#       8 safe_config = bigquery.QueryJobConfig()
#       9 first_result = client.query(first_query, job_config=safe_config)
# ---> 10 first_result.result().to_dataframe()
#
# ~\anaconda3\lib\site-packages\google\cloud\bigquery\job.py in result(self, timeout, retry)
#    2641             not complete in the given timeout.
#    2642         """
# -> 2643         super(QueryJob, self).result(timeout=timeout)
#    2644         # Return an iterator instead of returning the job.
#    2645         if not self._query_results:
#
# ~\anaconda3\lib\site-packages\google\cloud\bigquery\job.py in result(self, timeout)
#     686             self._begin()
#     687         # TODO: modify PollingFuture so it can pass a retry argument to done().
# ...
